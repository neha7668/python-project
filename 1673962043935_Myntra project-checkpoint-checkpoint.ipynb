# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Myntra=pd.read_csv(r"D:\Global Key Technologies\Data Science\Pandas_Myntra_Project/Myntra.csv",low_memory=False)
Myntra.head()
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %%
Myntra.isnull().sum()
# Out:
# URL                           0
# Product_id                    0
# BrandName                     0
# Category                      0
# Individual_category           0
# category_by_Gender            0
# Description                   0
# DiscountPrice (in Rs)    193158
# OriginalPrice (in Rs)         0
# DiscountOffer             74306
# SizeOption                    0
# Ratings                  336152
# Reviews                  336152
# dtype: int64

# %%
Myntra.dtypes
# Out:
# URL                       object
# Product_id                 int64
# BrandName                 object
# Category                  object
# Individual_category       object
# category_by_Gender        object
# Description               object
# DiscountPrice (in Rs)    float64
# OriginalPrice (in Rs)    float64
# DiscountOffer             object
# SizeOption                object
# Ratings                  float64
# Reviews                  float64
# dtype: object

# %%
Myntra[Myntra['DiscountOffer']=='45% OFF']
# Out:
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 37      https://www.myntra.com/jeans/wrogn/wrogn-men-b...     2477061
# 38      https://www.myntra.com/jeans/wrogn/wrogn-men-b...    10187401
# 66      https://www.myntra.com/kurta-sets/azira/azira-...    13141478
# 68      https://www.myntra.com/shirts/roadster/roadste...    11903990
# ...                                                   ...         ...
# 510632  https://www.myntra.com/tshirts/free-authority/...    13194072
# 510657  https://www.myntra.com/trousers/libas/libas-wo...    16373850
# 510685  https://www.myntra.com/shorts/aesthetic-nation...    15503148
# 510712  https://www.myntra.com/tops/stalk/stalk-mustar...    16624242
# 510744  https://www.myntra.com/trousers/bitterlime/bit...     1687290
#
#                BrandName     Category Individual_category category_by_Gender  \
# ...

# %%
Myntra[Myntra['Individual_category']=='trousers']
# Out:
#                                                       URL  Product_id  \
# 6       https://www.myntra.com/trousers/highlander/hig...     6744434
# 18      https://www.myntra.com/trousers/tokyo-talkies/...    12391750
# 26      https://www.myntra.com/trousers/zastraa/zastra...     9476129
# 42      https://www.myntra.com/trousers/sassafras/sass...     8643285
# 75      https://www.myntra.com/trousers/tokyo-talkies/...    13035312
# ...                                                   ...         ...
# 526491  https://www.myntra.com/trousers/de-moza/de-moz...    17705996
# 526494  https://www.myntra.com/trousers/max/max-women-...    17689806
# 526504  https://www.myntra.com/trousers/amukti/amukti-...    16003638
# 526508  https://www.myntra.com/trousers/akkriti-by-pan...     9252907
# 526550  https://www.myntra.com/trousers/gant/gant-wome...    17926052
#
#                     BrandName     Category Individual_category  \
# ...

# %%
Myntra[Myntra['DiscountOffer']>'80% OFF'].head(20)
# Out:
#                                                     URL  Product_id  \
# 182   https://www.myntra.com/tshirts/roadster/the-ro...    10968574
# 199   https://www.myntra.com/tshirts/mast--harbour/m...     8325391
# 243   https://www.myntra.com/tshirts/ether/ether-wom...     8610407
# 325   https://www.myntra.com/tshirts/mast--harbour/m...     8325439
# 356   https://www.myntra.com/tops/roadster/roadster-...     8964507
# 375   https://www.myntra.com/lounge-pants/xyxx/xyxx-...    10852560
# 434   https://www.myntra.com/trunk/one8-by-virat-koh...    11217408
# 473   https://www.myntra.com/dresses/ahalyaa/ahalyaa...     7193789
# 524   https://www.myntra.com/tshirts/veirdo/veirdo-m...    12915204
# 549   https://www.myntra.com/lounge-pants/xyxx/xyxx-...    10852574
# 561   https://www.myntra.com/tshirts/bewakoof/bewako...    12331848
# 592   https://www.myntra.com/tshirts/roadster/the-ro...    10301079
# 668   https://www.myntra.com/tshirts/roadster/roadst...     9740079
# ...

# %%
Myntra
# Out:
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4       https://www.myntra.com/tshirts/roadster/roadst...    11690882
# ...                                                   ...         ...
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# 526562  https://www.myntra.com/dresses/masaba/masaba-w...    12508700
# 526563  https://www.myntra.com/tshirts/jockey/jockey-w...    17856544
#
#           BrandName               Category Individual_category  \
# ...

# %%
Myntra2=Myntra.dropna()
Myntra2
# Out:
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 6       https://www.myntra.com/trousers/highlander/hig...     6744434
# ...                                                   ...         ...
# 188765  https://www.myntra.com/tshirts/hrx-by-hrithik-...     8379269
# 188766  https://www.myntra.com/track-pants/stylestone/...    12767048
# 188767  https://www.myntra.com/tshirts/hrx-by-hrithik-...    10106141
# 188768  https://www.myntra.com/tshirts/hrx-by-hrithik-...    11640324
# 188769  https://www.myntra.com/tshirts/hrx-by-hrithik-...    11639956
#
#                     BrandName               Category Individual_category  \
# ...

# %%
pd.pivot_table(Myntra2,index=['Product_id','BrandName','Individual_category'],values=['Ratings']).head(20)
# Out:
#                                                           Ratings
# Product_id BrandName                 Individual_category
# 66578      Enamor                    bra                      4.7
# 72725      Triumph                   bra                      4.4
# 72728      Triumph                   bra                      4.5
# 72736      Triumph                   bra                      4.4
# 72737      Triumph                   bra                      4.3
# 99350      Puma                      tshirts                  4.0
# 110269     Ira Soleil                kurtis                   3.6
# 203968     Clovia                    shapewear                3.3
# 219133     Slumber Jill              night-suits              4.3
# 234627     U.S. Polo Assn.           trousers                 3.3
# 266004     U.S. Polo Assn. Denim Co. jeans                    3.0
# 266005     U.S. Polo Assn. Denim Co. jeans                    4.0
# ...

# %%
pd.pivot_table(Myntra2,index=['Individual_category'],values=['Ratings']).head(20)
# Out:
#                       Ratings
# Individual_category
# baby-dolls           3.999462
# bath-robe            4.068205
# blazers              3.623961
# boots                3.650000
# boxers               4.024366
# bra                  4.075976
# briefs               4.164637
# burqas               4.009524
# camisoles            4.156839
# capris               4.237500
# casual-shoes         4.037500
# churidar             4.060465
# clothing-set         3.980000
# co-ords              4.046078
# coats                4.162500
# dhotis               4.011823
# dress-material       3.930462
# dresses              4.059655
# dungarees            3.800000
# dupatta              4.189720

# %%
Myntra2[Myntra2['Individual_category']=='heels']
# Out:
#                                                       URL  Product_id  \
# 170943  https://www.myntra.com/heels/sangria/sangria-m...    15145314
#
#        BrandName   Category Individual_category category_by_Gender  \
# 170943   Sangria  Plus Size               heels              Women
#
#                                               Description  \
# 170943  sangria multicoloured self striped mid top lac...
#
#         DiscountPrice (in Rs)  OriginalPrice (in Rs) DiscountOffer  \
# 170943                  734.0                 2099.0       65% OFF
#
#                                             SizeOption  Ratings  Reviews
# 170943  EURO36, EURO37, EURO38, EURO39, EURO40, EURO41      4.2      5.0

# %%
Myntra2['SizeOption'].value_counts()
# Out:
# S, M, L, XL, XXL                                                                                         23809
# S, M, L, XL                                                                                              11617
# XS, S, M, L, XL, XXL                                                                                      9960
# Onesize                                                                                                   9484
# S, M, L, XL, XXL, 3XL                                                                                     6338
#                                                                                                          ...
# 34DD, 36DD, 36E, 38DD, 38E, 40DD, 40E, 42B, 42C, 42D, 42DD, 42E, 44B, 44C, 44D, 44DD, 44E                    1
# 32B, 32C, 32D, 34A, 34B, 34C, 34D, 36B, 36C, 36D, 36DD, 38B, 38C, 38D                                        1
# ...

# %%
Myntra2['category_by_Gender'].value_counts().head(20)
# Out:
# Men      62219
# Women    55322
# Name: category_by_Gender, dtype: int64

# %%
Myntra2['Individual_category'].value_counts().sort_values(ascending=True).head(50)
# Out:
# heels                     1
# dungarees                 1
# sleepsuit                 1
# boots                     2
# harem-pants               2
# rain-jacket               4
# scarves                   5
# necklace-and-chains       5
# clothing-set              5
# swim-bottoms              7
# outdoor-masks             8
# coats                     8
# salwar-and-dupatta        8
# lingerie-accessories      8
# suits                    12
# jeggings                 20
# burqas                   21
# thermal-set              24
# patiala-and-dupatta      27
# waistcoat                33
# shrug                    35
# patiala                  37
# earrings                 37
# casual-shoes             40
# saree-accessories        44
# jumpsuit                 48
# robe                     49
# salwar                   49
# sports-sandals           54
# stoles                   71
# thermal-bottoms          74
# flats                    81
# churidar                 86
# ...

# %%
Myntra2['BrandName'].value_counts().sort_values(ascending=False)
# Out:
# HERE&NOW                 5108
# HRX by Hrithik Roshan    3706
# Roadster                 3346
# Sangria                  2875
# Puma                     2600
#                          ...
# Parcel Yard                 1
# Soxytoes                    1
# trueBrowns                  1
# Code 61                     1
# Donald Duck                 1
# Name: BrandName, Length: 1252, dtype: int64

# %%
Myntra2['DiscountPrice (in Rs)'].sum()
# Out:
# 121004311.0

# %%
Myntra2['DiscountPrice (in Rs)'].value_counts()
# Out:
# 599.0     2786
# 899.0     2124
# 999.0     1979
# 799.0     1727
# 1199.0    1623
#           ...
# 3048.0       1
# 310.0        1
# 186.0        1
# 1015.0       1
# 1658.0       1
# Name: DiscountPrice (in Rs), Length: 2718, dtype: int64

# %%
pd.pivot_table(Myntra2,index=['Individual_category'],values=['Ratings']).head(20)
# Out:
#                       Ratings
# Individual_category
# baby-dolls           3.999462
# bath-robe            4.068205
# blazers              3.623961
# boots                3.650000
# boxers               4.024366
# bra                  4.075976
# briefs               4.164637
# burqas               4.009524
# camisoles            4.156839
# capris               4.237500
# casual-shoes         4.037500
# churidar             4.060465
# clothing-set         3.980000
# co-ords              4.046078
# coats                4.162500
# dhotis               4.011823
# dress-material       3.930462
# dresses              4.059655
# dungarees            3.800000
# dupatta              4.189720

# %%
Myntra2.SizeOption.unique()
# Out:
# array(['28, 30, 32, 34, 36', 'S, M, L, XL', '38, 40, 42, 44, 46, 48', ...,
#        '30A, 30B, 30C, 30D, 32A, 32B, 32C, 32D, 32DD, 34A, 34B, 34C, 34D, 34DD, 36A, 36B, 36C, 36D, 36DD, 38B, 38C, 38D',
#        '26, 28, 30, 32, 34, 38, 40',
#        '32B, 32C, 32D, 32DD, 32E, 34A, 34B, 34C, 34D, 34DD, 34E, 36B, 36C, 36D, 36DD, 38B, 38C, 38D, 38E, 40C'],
#       dtype=object)

# %%
Myntra2[Myntra2['SizeOption']=="L".count()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 Myntra2[Myntra2['SizeOption']=="L".count(4)]
#
# TypeError: must be str, not int

# %%
Myntra2['Category'].value_counts()
# Out:
# Indian Wear                 29499
# Bottom Wear                 22091
# Topwear                     21232
# Lingerie & Sleep Wear       18685
# Plus Size                   10020
# Sports Wear                  9579
# Inner Wear &  Sleep Wear     6425
# Western                        10
# Name: Category, dtype: int64

# %%
Myntra2['DiscountOffer'].value_counts()
# Out:
# 50% OFF         13250
# 60% OFF         11751
# 40% OFF          8857
# 55% OFF          8240
# 65% OFF          7607
#                 ...
# Rs. 449 OFF         1
# Rs. 4700 OFF        1
# Rs. 2184 OFF        1
# Rs. 925 OFF         1
# Rs. 409 OFF         1
# Name: DiscountOffer, Length: 797, dtype: int64

# %%
Myntra2[(Myntra2.DiscountOffer=='50% OFF' ) & (Myntra2.category_by_Gender == 'Women')]
# Out:
#                                                       URL  Product_id  \
# 145     https://www.myntra.com/tops/sangria/sangria-na...     8860565
# 262     https://www.myntra.com/tops/sangria/sangria-bl...     8349519
# 292     https://www.myntra.com/tights/hrx-by-hrithik-r...     5842092
# 312     https://www.myntra.com/kurtas/sangria/sangria-...    11173950
# 445     https://www.myntra.com/tights/hrx-by-hrithik-r...     7695782
# ...                                                   ...         ...
# 188720  https://www.myntra.com/track-pants/hrx-by-hrit...     7688100
# 188725  https://www.myntra.com/tights/hrx-by-hrithik-r...     2293376
# 188729  https://www.myntra.com/tights/hrx-by-hrithik-r...     2262593
# 188733  https://www.myntra.com/track-pants/hrx-by-hrit...     2293431
# 188745  https://www.myntra.com/track-pants/hrx-by-hrit...    11812800
#
#                     BrandName     Category Individual_category  \
# ...

# %%
Myntra2[(Myntra2.DiscountOffer=='50% OFF' ) & (Myntra2.category_by_Gender == 'Men')]
# Out:
#                                                       URL  Product_id  \
# 40      https://www.myntra.com/shirts/roadster/roadste...    12918912
# 78      https://www.myntra.com/tshirts/wrogn/wrogn-men...    11363302
# 101     https://www.myntra.com/jeans/wrogn/wrogn-men-g...     1700734
# 123     https://www.myntra.com/tshirts/wrogn/wrogn-men...     2478316
# 152     https://www.myntra.com/tshirts/wrogn/wrogn-men...     2338881
# ...                                                   ...         ...
# 187725  https://www.myntra.com/tshirts/roadster/roadst...     2475892
# 187728  https://www.myntra.com/tshirts/roadster/roadst...     6149689
# 187733  https://www.myntra.com/tshirts/herenow/herenow...     8267997
# 187735  https://www.myntra.com/tshirts/moda-rapido/mod...     8683501
# 187737  https://www.myntra.com/tshirts/roadster/roadst...     8938109
#
#           BrandName     Category Individual_category category_by_Gender  \
# ...

# %%
pd.pivot_table(Myntra2,index=['Individual_category','category_by_Gender'],values=['Ratings'])
# Out:
#                                          Ratings
# Individual_category category_by_Gender
# baby-dolls          Women               3.999462
# bath-robe           Men                 4.206494
#                     Women               3.977966
# blazers             Men                 3.623961
# boots               Women               3.650000
# ...                                          ...
# trunk               Men                 4.124694
# tshirts             Men                 4.173639
#                     Women               4.263794
# tunics              Women               4.049533
# waistcoat           Men                 3.984848
#
# [118 rows x 1 columns]
